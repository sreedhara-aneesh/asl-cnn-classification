# %% [markdown]
# # Testing Variations in Convolutional Layers

# %% [markdown]
# ## Setup and configuration

# %% [markdown]
# **Initial setup:** data is pulled from Kaggle, follow the steps below to get that set up.
#
# 1.   You'll need to upload your `kaggle.json` (Kaggle Website > Account > API > Create New API Token) to the working directory.
#
# 2.   Comment out the below code block after your first run to prevent re-downloading data for no reason.

# %%
# !pip install kaggle
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download grassknoted/asl-alphabet --unzip

# %% [markdown]
# **Optional:** comment out the code block below if you would like to see Tensorflow logs.

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# %% [markdown]
# **Optional:** comment out the code block below if you want to see warnings.

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Force Google Colab to use latest version of Tensorflow to avoid miscellaneous issues.

# %%
# !pip install tensorflow -U

# %% [markdown]
# Other imports.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf
from tensorflow import keras
import os

from IPython.display import Markdown
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Model creation

# %% [markdown]
# ### Load and preprocess data

# %% [markdown]
# Create training and validation datasets.

# %%
batch_size = 64
image_size = 64

train_dir = './asl_alphabet_train/asl_alphabet_train'

train_ds, test_val_ds = tf.keras.utils.image_dataset_from_directory(
  train_dir,
  validation_split=0.4,
  subset="both",
  seed=123,
  image_size=(image_size, image_size),
  batch_size=batch_size
)

num_classes = len(train_ds.class_names)
# Out:
# Found 87000 files belonging to 29 classes.
# Using 52200 files for training.
# Using 34800 files for validation.

# %%
test_ds, val_ds = train_test_split(
  list(test_val_ds.unbatch().as_numpy_iterator()), 
  train_size=0.5, 
  random_state=123
)

print(f'Using {len(test_ds)} files for testing.')
print(f'Using {len(val_ds)} files for validation.')

test_ds = np.array(test_ds).transpose().tolist()
val_ds = np.array(val_ds).transpose().tolist()

test_ds = tf.data.Dataset.from_tensor_slices((test_ds[0], test_ds[1])).batch(batch_size)
val_ds = tf.data.Dataset.from_tensor_slices((val_ds[0], val_ds[1])).batch(batch_size)
# Out:
# Using 17400 files for testing.
# Using 17400 files for validation.

# %% [markdown]
# ### Create and fit models

# %% [markdown]
# Multiple models are created with varying numbers of convolutional layers.
#
# The choices of layer numbers are set via the `num_conv_layers_choices` array.

# %%
model_data = []

num_conv_layers_choices = [1, 2, 3, 4]

for num_conv_layers in num_conv_layers_choices:
  
  layers = [
    tf.keras.layers.Rescaling(1./255),
    tf.keras.layers.Conv2D(32, 3, activation='relu'),
    tf.keras.layers.MaxPooling2D()
  ]

  for i in range(1, num_conv_layers):
    layers += [
      tf.keras.layers.Conv2D(64, 3, activation='relu'),
      tf.keras.layers.MaxPooling2D(),
    ]

  layers += [
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(num_classes, activation='softmax')
  ]

  model = tf.keras.Sequential(layers)

  model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy'],
  )

  early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2)
  
  model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    callbacks=[early_stop],
    verbose=1 # set to 1 or 2 for reporting, 0 for silent
  )

  model_data.append({
    "model": model,
    "num_conv_layers": num_conv_layers,
    "metrics": pd.DataFrame(model.history.history)
  })
# Out:
# Epoch 1/50
# 816/816 [==============================] - 13s 15ms/step - loss: 1.9803 - accuracy: 0.4164 - val_loss: 1.1737 - val_accuracy: 0.6349
# Epoch 2/50
# 816/816 [==============================] - 14s 18ms/step - loss: 0.8382 - accuracy: 0.7430 - val_loss: 0.6941 - val_accuracy: 0.7868
# Epoch 3/50
# 816/816 [==============================] - 18s 22ms/step - loss: 0.5133 - accuracy: 0.8485 - val_loss: 0.4597 - val_accuracy: 0.8618
# Epoch 4/50
# 816/816 [==============================] - 20s 24ms/step - loss: 0.3511 - accuracy: 0.8987 - val_loss: 0.3310 - val_accuracy: 0.8998
# Epoch 5/50
# 816/816 [==============================] - 17s 21ms/step - loss: 0.2496 - accuracy: 0.9290 - val_loss: 0.2706 - val_accuracy: 0.9186
# Epoch 6/50
# 816/816 [==============================] - 14s 17ms/step - loss: 0.1794 - accuracy: 0.9515 - val_loss: 0.2085 - val_accuracy: 0.9397
# Epoch 7/50
# 816/816 [==============================] - 14s 17ms/step - loss: 0.1341 - accuracy: 0.9661 - val_loss: 0.1955 - val_accuracy: 0.9391
# Epoch 8/50
# 816/816 [==============================] - 13s 16ms/step - loss: 0.1058 - accuracy: 0.9728 - val_loss: 0.1954 - val_accuracy: 0.9367
# Epoch 9/50
# 816/816 [==============================] - 15s 18ms/step - loss: 0.0822 - accuracy: 0.9800 - val_loss: 0.1848 - val_accuracy: 0.9401
# Epoch 10/50
# 816/816 [==============================] - 16s 19ms/step - loss: 0.0675 - accuracy: 0.9835 - val_loss: 0.1497 - val_accuracy: 0.9537
# Epoch 11/50
# 816/816 [==============================] - 14s 18ms/step - loss: 0.0548 - accuracy: 0.9874 - val_loss: 0.1547 - val_accuracy: 0.9503
# Epoch 12/50
# 816/816 [==============================] - 14s 17ms/step - loss: 0.0483 - accuracy: 0.9879 - val_loss: 0.1157 - val_accuracy: 0.9641
# Epoch 13/50
# 816/816 [==============================] - 14s 17ms/step - loss: 0.0405 - accuracy: 0.9903 - val_loss: 0.1057 - val_accuracy: 0.9689
# Epoch 14/50
# 816/816 [==============================] - 14s 17ms/step - loss: 0.0347 - accuracy: 0.9917 - val_loss: 0.1402 - val_accuracy: 0.9554
# Epoch 15/50
# 816/816 [==============================] - 14s 17ms/step - loss: 0.0384 - accuracy: 0.9893 - val_loss: 0.1225 - val_accuracy: 0.9628
# Epoch 1/50
# 816/816 [==============================] - 16s 19ms/step - loss: 1.2556 - accuracy: 0.6284 - val_loss: 0.4153 - val_accuracy: 0.8729
# Epoch 2/50
# 816/816 [==============================] - 17s 21ms/step - loss: 0.2338 - accuracy: 0.9276 - val_loss: 0.1899 - val_accuracy: 0.9353
# Epoch 3/50
# 816/816 [==============================] - 15s 19ms/step - loss: 0.0978 - accuracy: 0.9705 - val_loss: 0.1160 - val_accuracy: 0.9644
# Epoch 4/50
# 816/816 [==============================] - 14s 18ms/step - loss: 0.0646 - accuracy: 0.9810 - val_loss: 0.0694 - val_accuracy: 0.9783
# Epoch 5/50
# 816/816 [==============================] - 14s 17ms/step - loss: 0.0487 - accuracy: 0.9850 - val_loss: 0.0592 - val_accuracy: 0.9811
# Epoch 6/50
# 816/816 [==============================] - 14s 17ms/step - loss: 0.0437 - accuracy: 0.9866 - val_loss: 0.0582 - val_accuracy: 0.9805
# Epoch 7/50
# 816/816 [==============================] - 14s 17ms/step - loss: 0.0336 - accuracy: 0.9897 - val_loss: 0.0555 - val_accuracy: 0.9835
# Epoch 8/50
# 816/816 [==============================] - 14s 17ms/step - loss: 0.0306 - accuracy: 0.9911 - val_loss: 0.0748 - val_accuracy: 0.9766
# Epoch 9/50
# 816/816 [==============================] - 14s 17ms/step - loss: 0.0241 - accuracy: 0.9929 - val_loss: 0.0584 - val_accuracy: 0.9834
# Epoch 1/50
# 816/816 [==============================] - 17s 21ms/step - loss: 1.1918 - accuracy: 0.6449 - val_loss: 0.3028 - val_accuracy: 0.9052
# Epoch 2/50
# 816/816 [==============================] - 16s 20ms/step - loss: 0.1874 - accuracy: 0.9408 - val_loss: 0.1168 - val_accuracy: 0.9641
# Epoch 3/50
# 816/816 [==============================] - 16s 19ms/step - loss: 0.0824 - accuracy: 0.9740 - val_loss: 0.0882 - val_accuracy: 0.9719
# Epoch 4/50
# 816/816 [==============================] - 15s 18ms/step - loss: 0.0492 - accuracy: 0.9846 - val_loss: 0.0402 - val_accuracy: 0.9891
# Epoch 5/50
# 816/816 [==============================] - 15s 18ms/step - loss: 0.0496 - accuracy: 0.9850 - val_loss: 0.0626 - val_accuracy: 0.9799
# Epoch 6/50
# 816/816 [==============================] - 14s 18ms/step - loss: 0.0300 - accuracy: 0.9909 - val_loss: 0.0430 - val_accuracy: 0.9883
# Epoch 1/50
# 816/816 [==============================] - 15s 18ms/step - loss: 1.2855 - accuracy: 0.6105 - val_loss: 0.5276 - val_accuracy: 0.8237
# Epoch 2/50
# 816/816 [==============================] - 15s 18ms/step - loss: 0.2462 - accuracy: 0.9170 - val_loss: 0.1644 - val_accuracy: 0.9421
# Epoch 3/50
# 816/816 [==============================] - 15s 18ms/step - loss: 0.1214 - accuracy: 0.9590 - val_loss: 0.0699 - val_accuracy: 0.9763
# Epoch 4/50
# 816/816 [==============================] - 18s 22ms/step - loss: 0.0725 - accuracy: 0.9759 - val_loss: 0.0553 - val_accuracy: 0.9825
# Epoch 5/50
# 816/816 [==============================] - 16s 20ms/step - loss: 0.0624 - accuracy: 0.9794 - val_loss: 0.0412 - val_accuracy: 0.9872
# Epoch 6/50
# 816/816 [==============================] - 15s 18ms/step - loss: 0.0471 - accuracy: 0.9846 - val_loss: 0.0350 - val_accuracy: 0.9898
# Epoch 7/50
# 816/816 [==============================] - 15s 18ms/step - loss: 0.0386 - accuracy: 0.9877 - val_loss: 0.0489 - val_accuracy: 0.9855
# Epoch 8/50
# 816/816 [==============================] - 15s 18ms/step - loss: 0.0416 - accuracy: 0.9871 - val_loss: 0.0312 - val_accuracy: 0.9900
# Epoch 9/50
# 816/816 [==============================] - 15s 18ms/step - loss: 0.0339 - accuracy: 0.9898 - val_loss: 0.0863 - val_accuracy: 0.9739
# Epoch 10/50
# 816/816 [==============================] - 15s 18ms/step - loss: 0.0160 - accuracy: 0.9949 - val_loss: 0.0183 - val_accuracy: 0.9957
# Epoch 11/50
# 816/816 [==============================] - 16s 20ms/step - loss: 0.0388 - accuracy: 0.9883 - val_loss: 0.0354 - val_accuracy: 0.9890
# Epoch 12/50
# 816/816 [==============================] - 17s 21ms/step - loss: 0.0291 - accuracy: 0.9917 - val_loss: 0.0319 - val_accuracy: 0.9908

# %% [markdown]
# ## Model evaluation

# %% [markdown]
# ### Display model metrics

# %%
display(Markdown("# Model metrics"))

for datum in model_data:

  model = datum['model']
  num_conv_layers = datum['num_conv_layers']
  metrics = datum['metrics']

  display(Markdown(f"## Convolutional layers = {num_conv_layers}"))
  
  display(metrics[['accuracy', 'val_accuracy', 'loss', 'val_loss']])

  metrics[['accuracy','val_accuracy']].plot()
  plt.show()

  metrics[['loss','val_loss']].plot()
  plt.show()
# Out:
# # Model metrics
# ## Convolutional layers = 1
#     accuracy  val_accuracy      loss  val_loss
# 0   0.416437      0.634943  1.980344  1.173710
# 1   0.743027      0.786839  0.838250  0.694119
# 2   0.848506      0.861839  0.513250  0.459746
# 3   0.898716      0.899770  0.351141  0.331001
# 4   0.929042      0.918621  0.249613  0.270629
# 5   0.951475      0.939713  0.179436  0.208509
# 6   0.966092      0.939080  0.134138  0.195549
# 7   0.972797      0.936724  0.105795  0.195385
# 8   0.980000      0.940057  0.082191  0.184812
# 9   0.983467      0.953678  0.067457  0.149730
# 10  0.987356      0.950345  0.054764  0.154669
# 11  0.987893      0.964138  0.048284  0.115748
# 12  0.990345      0.968851  0.040456  0.105722
# 13  0.991705      0.955402  0.034738  0.140155
# 14  0.989272      0.962759  0.038372  0.122460
# ## Convolutional layers = 2
#    accuracy  val_accuracy      loss  val_loss
# 0  0.628410      0.872874  1.255572  0.415315
# 1  0.927605      0.935345  0.233819  0.189900
# 2  0.970517      0.964368  0.097751  0.115953
# 3  0.980977      0.978276  0.064576  0.069367
# 4  0.985038      0.981092  0.048697  0.059250
# 5  0.986647      0.980517  0.043714  0.058212
# 6  0.989713      0.983506  0.033628  0.055514
# 7  0.991092      0.976609  0.030580  0.074799
# 8  0.992873      0.983448  0.024119  0.058428
# ## Convolutional layers = 3
#    accuracy  val_accuracy      loss  val_loss
# 0  0.644866      0.905172  1.191817  0.302805
# 1  0.940766      0.964080  0.187405  0.116814
# 2  0.974004      0.971897  0.082378  0.088196
# 3  0.984636      0.989138  0.049233  0.040211
# 4  0.984962      0.979943  0.049569  0.062617
# 5  0.990919      0.988276  0.029954  0.042990
# ## Convolutional layers = 4
#     accuracy  val_accuracy      loss  val_loss
# 0   0.610517      0.823736  1.285505  0.527582
# 1   0.916992      0.942069  0.246186  0.164433
# 2   0.959023      0.976322  0.121433  0.069910
# 3   0.975919      0.982471  0.072486  0.055327
# 4   0.979387      0.987184  0.062413  0.041196
# 5   0.984617      0.989770  0.047082  0.035021
# 6   0.987663      0.985517  0.038596  0.048866
# 7   0.987088      0.990000  0.041611  0.031194
# 8   0.989770      0.973851  0.033945  0.086330
# 9   0.994923      0.995690  0.015960  0.018311
# 10  0.988276      0.988966  0.038774  0.035373
# 11  0.991686      0.990805  0.029074  0.031918

# %% [markdown]
# ### Display model prediction performance

# %%
display(Markdown("# Model prediction performance"))

predict_ds = test_ds

for datum in model_data:

  model = datum['model']
  num_conv_layers = datum['num_conv_layers']
  metrics = datum['metrics']

  display(Markdown(f"## Convolutional layers = {num_conv_layers}"))

  y_pred_raw = model.predict(predict_ds)
  y_pred = np.argmax(y_pred_raw, axis=1)
  y_true = [y.numpy() for x, y in predict_ds.unbatch()]
  print(classification_report(y_true, y_pred))
  
  sns.heatmap(confusion_matrix(y_pred,y_true))
  plt.show()
# Out:
# # Model prediction performance
# ## Convolutional layers = 1
# 272/272 [==============================] - 2s 4ms/step
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96       624
#            1       0.94      0.98      0.96       609
#            2       0.99      0.99      0.99       576
#            3       0.99      0.97      0.98       580
#            4       0.97      0.94      0.96       596
#            5       0.98      0.99      0.99       597
#            6       0.99      0.93      0.96       608
#            7       0.93      0.99      0.96       588
#            8       0.98      0.97      0.98       615
#            9       0.99      0.99      0.99       614
#           10       0.98      0.98      0.98       592
#           11       0.98      0.93      0.96       623
#           12       0.94      0.97      0.95       632
#           13       0.98      0.96      0.97       579
#           14       0.89      0.99      0.93       582
#           15       0.99      0.97      0.98       601
#           16       0.98      0.99      0.99       577
#           17       0.95      0.97      0.96       606
#           18       0.95      0.96      0.96       599
#           19       0.98      0.93      0.95       595
#           20       0.94      0.95      0.94       656
#           21       0.94      0.93      0.94       602
#           22       0.92      0.98      0.95       635
#           23       0.98      0.96      0.97       602
#           24       0.96      0.96      0.96       603
#           25       0.99      0.90      0.94       571
#           26       0.94      0.98      0.96       595
#           27       1.00      1.00      1.00       598
#           28       0.99      0.95      0.97       545
#
#     accuracy                           0.96     17400
#    macro avg       0.97      0.96      0.96     17400
# weighted avg       0.97      0.96      0.96     17400
# ## Convolutional layers = 2
# 272/272 [==============================] - 1s 4ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98       624
#            1       0.98      1.00      0.99       609
#            2       1.00      1.00      1.00       576
#            3       1.00      0.98      0.99       580
#            4       0.96      0.98      0.97       596
#            5       0.98      1.00      0.99       597
#            6       0.99      1.00      0.99       608
#            7       1.00      0.99      0.99       588
#            8       0.96      0.99      0.98       615
#            9       0.99      1.00      0.99       614
#           10       0.96      1.00      0.98       592
#           11       1.00      0.99      1.00       623
#           12       0.97      0.98      0.98       632
#           13       0.98      1.00      0.99       579
#           14       0.97      0.99      0.98       582
#           15       1.00      1.00      1.00       601
#           16       0.98      1.00      0.99       577
#           17       0.99      0.94      0.96       606
#           18       1.00      0.83      0.91       599
#           19       0.97      0.98      0.98       595
#           20       0.95      0.98      0.96       656
#           21       0.97      0.97      0.97       602
#           22       0.97      1.00      0.98       635
#           23       0.99      0.97      0.98       602
#           24       0.98      0.99      0.98       603
#           25       0.98      0.99      0.99       571
#           26       1.00      0.98      0.99       595
#           27       1.00      1.00      1.00       598
#           28       1.00      1.00      1.00       545
#
#     accuracy                           0.98     17400
#    macro avg       0.98      0.98      0.98     17400
# weighted avg       0.98      0.98      0.98     17400
# ## Convolutional layers = 3
# 272/272 [==============================] - 1s 4ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       624
#            1       0.98      1.00      0.99       609
#            2       1.00      0.99      0.99       576
#            3       0.99      1.00      0.99       580
#            4       1.00      0.98      0.99       596
#            5       1.00      0.98      0.99       597
#            6       0.99      0.99      0.99       608
#            7       0.97      1.00      0.98       588
#            8       0.99      1.00      0.99       615
#            9       1.00      0.98      0.99       614
#           10       0.93      1.00      0.96       592
#           11       1.00      0.99      0.99       623
#           12       0.99      0.98      0.98       632
#           13       0.97      1.00      0.99       579
#           14       0.98      0.99      0.99       582
#           15       0.99      0.98      0.99       601
#           16       1.00      0.99      0.99       577
#           17       1.00      0.96      0.98       606
#           18       0.98      0.98      0.98       599
#           19       1.00      0.99      0.99       595
#           20       0.98      0.99      0.98       656
#           21       0.98      0.97      0.97       602
#           22       0.98      1.00      0.99       635
#           23       0.99      0.98      0.99       602
#           24       1.00      1.00      1.00       603
#           25       1.00      0.99      1.00       571
#           26       1.00      1.00      1.00       595
#           27       1.00      1.00      1.00       598
#           28       0.99      1.00      0.99       545
#
#     accuracy                           0.99     17400
#    macro avg       0.99      0.99      0.99     17400
# weighted avg       0.99      0.99      0.99     17400
# ## Convolutional layers = 4
# 272/272 [==============================] - 1s 4ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       624
#            1       1.00      0.99      1.00       609
#            2       1.00      1.00      1.00       576
#            3       1.00      0.99      0.99       580
#            4       0.99      1.00      0.99       596
#            5       0.98      1.00      0.99       597
#            6       1.00      0.99      1.00       608
#            7       0.99      0.99      0.99       588
#            8       0.99      1.00      1.00       615
#            9       0.99      1.00      0.99       614
#           10       0.99      0.97      0.98       592
#           11       1.00      1.00      1.00       623
#           12       0.99      0.99      0.99       632
#           13       0.98      0.99      0.99       579
#           14       1.00      0.99      0.99       582
#           15       0.96      1.00      0.98       601
#           16       0.99      0.98      0.99       577
#           17       1.00      0.99      0.99       606
#           18       0.99      1.00      1.00       599
#           19       1.00      0.98      0.99       595
#           20       0.99      0.98      0.98       656
#           21       0.93      1.00      0.96       602
#           22       1.00      0.96      0.98       635
#           23       0.99      1.00      1.00       602
#           24       1.00      0.99      1.00       603
#           25       1.00      0.99      1.00       571
#           26       1.00      0.98      0.99       595
#           27       1.00      1.00      1.00       598
#           28       1.00      1.00      1.00       545
#
#     accuracy                           0.99     17400
#    macro avg       0.99      0.99      0.99     17400
# weighted avg       0.99      0.99      0.99     17400

# %% [markdown]
# ## Saving models

# %% [markdown]
# **Optional:** uncomment below code block to save models to `models` folder.

# %%
for datum in model_data:
    datum['model'].save(f"models/{datum['num_conv_layers']}_conv_layers.h5")
    print(f"Model saved to: models/{datum['num_conv_layers']}_conv_layers.h5")
# Out:
# Model saved to: models/1_conv_layers.h5
# Model saved to: models/2_conv_layers.h5
# Model saved to: models/3_conv_layers.h5
# Model saved to: models/4_conv_layers.h5
